# %% [markdown]
# # Edit Analysis
# This analysis looks at the degree to which edit activity changed on the articles posted to the Social Media Traffic Report (https://en.wikipedia.org/wiki/User:HostBot/Social_media_traffic_report). Ideally, this would also include the page protection data and include controls, but this analysis should at least give us a rough sense of impact.

# %%
# !pip install mediawiki-utilities
# Out:
# Requirement already satisfied: mediawiki-utilities in /srv/home/isaacj/venv/lib/python3.5/site-packages
# Requirement already satisfied: pymysql>=0.6.2 in /usr/lib/python3/dist-packages (from mediawiki-utilities)
# Requirement already satisfied: requests>=2.4 in /srv/home/isaacj/venv/lib/python3.5/site-packages (from mediawiki-utilities)
# Requirement already satisfied: chardet<4,>=3.0.2 in /srv/home/isaacj/venv/lib/python3.5/site-packages (from requests>=2.4->mediawiki-utilities)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/home/isaacj/venv/lib/python3.5/site-packages (from requests>=2.4->mediawiki-utilities)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/home/isaacj/venv/lib/python3.5/site-packages (from requests>=2.4->mediawiki-utilities)
# Requirement already satisfied: idna<3,>=2.5 in /srv/home/isaacj/venv/lib/python3.5/site-packages (from requests>=2.4->mediawiki-utilities)

# %%
import copy
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import time
import traceback

from mw.lib import reverts
import numpy as np
import pandas as pd
import requests

# %%
# Load in data of unique page IDs posted to report and first date they appeared
pageids_path = "../social-media-traffic-reports/data/pageids_firstdate.tsv"
pageids_name = 'smtr_pageids'
df = pd.read_csv(pageids_path, sep='\t', header=None)
df.columns = ['pageid', 'first_date']
df.head()
# Out:
#      pageid  first_date
# 0    933889  2020_04_15
# 1    565250  2020_05_15
# 2   2473996  2020_04_21
# 3    327694  2020_04_24
# 4  28344340  2020_03_28

# %%
def process_revapi(url, base_params, add_params=None, session=None):
    """Get all revisions between two revision IDs"""
    if session is None:
        session = requests.Session()
    params = copy.deepcopy(base_params)
    if add_params:
        for p,v in add_params.items():
            params[p] = v
    revids = []
    timestamps = []
    sha1s = []
    continue_params = {}
    while True:
        query_params = copy.deepcopy(params)
        query_params.update(continue_params)
        result = session.get(url=url, params=query_params)
        result_json = result.json()
        best_match = result_json['query']['pages'][0]
        if 'revisions' in best_match:
            revids.extend([rev['revid'] for rev in best_match['revisions']])
            timestamps.extend([rev['timestamp'] for rev in best_match['revisions']])
            sha1s.extend([rev['sha1'] for rev in best_match['revisions']])
        else:
            print("Not found: {0}".format(best_match))
        if 'continue' not in result_json:
            break
        continue_params = result_json['continue']

    return revids, timestamps, sha1s

# %%
def get_num_reverts(revids, timestamps, sha1s):
    """Get revision that was current for a date (excluding reverts).
    
    Params:
        revids: list of revision IDs, sorted from oldest to newest
        timestamps: list of corresponding timestamps
        sha1s: list of sha1 hashes for each rev (used for determining whether a revision was reverted)
    Returns:
        revision ID (int) associated with that date or None if date comes before revision history.
    """
    # make sure revids, timestamps, sha1s are all of same length and sorted oldest to newest
    if len(revids) != len(timestamps) or len(revids) != len(sha1s):
        raise Exception("Must have equal number of revids (), timestamps (), and sha1s ().".format(
            len(revids), len(timestamps), len(sha1s)))
    if sorted(revids) != revids or sorted(timestamps) != timestamps:
        raise Exception("Revisions must be sorted oldest to newest.")
    
    # determine which revisions were reverted (based on the history provided)
    num_reverts = len([r for r in reverts.detect([(s,{'rev_id':r}) for r,s in zip(revids, sha1s)])])
            
    return num_reverts

# %%
def get_rev_history(df, pid_col, revid_start_col, revid_end_col):
    # Generate full revision history for articles between two revision IDs.
    base_params = {
        "action": "query",
        "prop": "revisions",
        "rvlimit": "500",
        "rvprop": "ids|timestamp|sha1",
        "rvdir": "newer",
        "rvslots": "main",
        "formatversion": "2",
        "format": "json"
        }
    base_url = "https://en.wikipedia.org/w/api.php"
    with requests.Session() as session:
        for i, row in enumerate(df.itertuples()):
            # English article rev history
            row = row._asdict()
            try:
                page_params = {"pageids": row[pid_col], "rvstartid": int(row[revid_start_col]), "rvendid": int(row[revid_end_col])}        
                revids, times, sha1s = process_revapi(url=base_url, base_params=base_params, add_params=page_params, session=session)
            except Exception:
                print('Failed to get history: {0}'.format(row))
                revids = None
                times = None
                sha1s = None
            yield i, revids, times, sha1s

# %%
def revision_initial(page, date=None, session=None):
    """Gets the version of an article at a specific date.
    
    If no date provide, defaults to getting the first revision of the article.
    Parameters:
      page: integer page ID
      date: if provided, this returns the revision at that date -- e.g., "2018-01-01T00:00:00Z"
      session: requests.Session object for hitting the API.
    """
    if session is None:
        session = requests.Session()

    base_url = "https://en.wikipedia.org/w/api.php"

    # default to first revision of an article
    params = {
        "action": "query",
        "prop": "revisions",
        "pageids": page,
        "rvlimit": "1",
        "rvprop": "ids|timestamp|user|comment|content",
        "rvdir": "newer",  # start at oldest revision
        "rvstart": "1999-01-01T00:00:00Z",  # time before Wikipedia so guarantee always getting first revision
        "rvslots": "main",
        "formatversion": "2",
        "format": "json"
    }
    # if date provided, provide revision at that date
    if date:
        params['rvdir'] = 'older'
        params['rvstart'] = date

    revid = None
    timestamp = None
    try:
        result = session.get(url=base_url, params=params)
        result_json = result.json()
        best_match = result_json['query']['pages'][0]
        if 'revisions' in best_match:
            rev = best_match['revisions'][0]
            revid = rev['revid']
            timestamp = rev['timestamp']
        else:
            print("Not found: {0}".format(best_match))
    except Exception:
        traceback.print_exc()
    return revid, timestamp

# %%
def alter_date(date_str, hours=0, days=0, months=0, minutes=0, add=True):
    """ Add time to input date string."""
    dt_format = '%Y_%m_%d'
    output_format = '%Y-%m-%dT00:00:00Z'
    if type(date_str) != str:
        return None
    dt = datetime.strptime(date_str, dt_format)
    if add:
        dt = dt + timedelta(days=days, hours=hours, minutes=minutes)
        if months:
            dt = dt + relativedelta(months=months)
    else:
        dt = dt - timedelta(days=days, hours=hours, minutes=minutes)
        if months:
            dt = dt - relativedelta(months=months)
    return datetime.strftime(dt, output_format)

# %%
# gather revision IDs / dates for two weeks prior/after posting.
rev_info = {}
with requests.Session() as session:
    for row in df.itertuples():
        pid = row.pageid
        two_weeks_ago = alter_date(date_str=row.first_date, days=14, add=False)
        two_weeks_later = alter_date(date_str=row.first_date, days=14, add=True)
        revid_two_weeks_prior, revdate_two_weeks_prior = revision_initial(page=row.pageid, date=two_weeks_ago, session=session)
        revid_two_weeks_later, revdate_two_weeks_later = revision_initial(page=row.pageid, date=two_weeks_later, session=session)
        rev_info[pid] = {'revid_two_weeks_prior':revid_two_weeks_prior, 'revdate_two_weeks_prior':revdate_two_weeks_prior,
                         'revid_two_weeks_later':revid_two_weeks_later, 'revdate_two_weeks_later':revdate_two_weeks_later}
        time.sleep(0.1)
        if len(rev_info) % 100 == 0:
            print("{0}/{1} complete".format(len(rev_info), len(df)))
# Out:
# Not found: {'title': 'Dalgona coffee', 'pageid': 63520964, 'ns': 0}
# 100/3324 complete
# 200/3324 complete
# 300/3324 complete
# Not found: {'title': 'Timeline of the COVID-19 pandemic in the Philippines', 'pageid': 63488816, 'ns': 0}
# 400/3324 complete
# Not found: {'title': 'COVID-19 pandemic in South Africa', 'pageid': 63300653, 'ns': 0}
# 500/3324 complete
# Not found: {'title': 'Max C. Starkloff', 'pageid': 63374708, 'ns': 0}
# 600/3324 complete
# Not found: {'title': 'Tom Moore (fundraiser)', 'pageid': 63661726, 'ns': 0}
# 700/3324 complete
# Not found: {'title': 'Amy Acton', 'pageid': 63391478, 'ns': 0}
# Not found: {'title': 'Shooting of Ahmaud Arbery', 'pageid': 63858312, 'ns': 0}
# 800/3324 complete
# Not found: {'title': 'Anti-Mask League of San Francisco', 'pageid': 63716341, 'ns': 0}
# Not found: {'title': '2020 stock market crash', 'pageid': 63358914, 'ns': 0}
# Not found: {'pageid': 12306449, 'missing': True}
# Not found: {'pageid': 12306449, 'missing': True}
# 900/3324 complete
# 1000/3324 complete
# 1100/3324 complete
# 1200/3324 complete
# Not found: {'title': 'Coronavirus Act 2020', 'pageid': 63407978, 'ns': 0}
# 1300/3324 complete
# 1400/3324 complete
# Not found: {'title': 'Tech 4 Peace', 'pageid': 63593359, 'ns': 0}
# 1500/3324 complete
# Not found: {'title': 'Bureau of Immigration Bicutan Detention Center', 'pageid': 63786676, 'ns': 0}
# Not found: {'title': 'Pham Quang Khiem', 'pageid': 63598431, 'ns': 0}
# Not found: {'title': 'COVID-19 pandemic in Belgium', 'pageid': 63262573, 'ns': 0}
# 1600/3324 complete
# 1700/3324 complete
# Not found: {'title': 'Philippine COVID-19 testing controversy', 'pageid': 63443214, 'ns': 0}
# 1800/3324 complete
# 1900/3324 complete
# Not found: {'title': '2020 Nova Scotia attacks', 'pageid': 63705765, 'ns': 0}
# 2000/3324 complete
# Not found: {'title': 'Draft:Hoaxed (2019 Film)', 'pageid': 63700453, 'ns': 118}
# 2100/3324 complete
# 2200/3324 complete
# Not found: {'title': 'Crimson Contagion', 'pageid': 63468897, 'ns': 0}
# Not found: {'title': 'COVID-19 pandemic in the Republic of Ireland', 'pageid': 63264158, 'ns': 0}
# Not found: {'pageid': 48887208, 'missing': True}
# Not found: {'pageid': 48887208, 'missing': True}
# Not found: {'title': '2020 Tablighi Jamaat coronavirus hotspot in Delhi', 'pageid': 63542764, 'ns': 0}
# 2300/3324 complete
# Not found: {'pageid': 63378986, 'missing': True}
# Not found: {'pageid': 63378986, 'missing': True}
# Not found: {'title': 'COVID-19 pandemic in Karnataka', 'pageid': 63370168, 'ns': 0}
# Not found: {'title': 'Venezuelan patrol boat Naiguatá', 'pageid': 63551161, 'ns': 0}
# 2400/3324 complete
# Not found: {'title': 'Bidyanondo Foundation', 'pageid': 63657791, 'ns': 0}
# Not found: {'title': 'Exercise Cygnus', 'pageid': 63510352, 'ns': 0}
# Not found: {'title': 'Brian Harrison (government official)', 'pageid': 63739735, 'ns': 0}
# Not found: {'title': 'Macuto Bay raid', 'pageid': 63862683, 'ns': 0}
# Not found: {'title': 'Draft:MortaL (streamer)', 'pageid': 63346632, 'ns': 118}
# Not found: {'title': 'COVID-19 pandemic in Slovakia', 'pageid': 63300608, 'ns': 0}
# 2500/3324 complete
# Not found: {'title': 'Bayanihan to Heal as One Act', 'pageid': 63469659, 'ns': 0}
# 2600/3324 complete
# Not found: {'title': 'COVID-19 pandemic in Virginia', 'pageid': 63363332, 'ns': 0}
# 2700/3324 complete
# Not found: {'title': 'COVID-19 pandemic in Russia', 'pageid': 63263950, 'ns': 0}
# 2800/3324 complete
# Not found: {'pageid': 50174864, 'missing': True}
# Not found: {'pageid': 50174864, 'missing': True}
# 2900/3324 complete
# Not found: {'pageid': 63896761, 'missing': True}
# Not found: {'pageid': 63896761, 'missing': True}
# 3000/3324 complete
# 3100/3324 complete
# Not found: {'title': 'Plandemic', 'pageid': 63888997, 'ns': 0}
# 3200/3324 complete
# Not found: {'title': 'Kizzmekia Corbett', 'pageid': 63512325, 'ns': 0}
# 3300/3324 complete

# %%
for c in ['revid_two_weeks_prior', 'revdate_two_weeks_prior', 'revid_two_weeks_later', 'revdate_two_weeks_later']:
    df[c] = df['pageid'].apply(lambda x: rev_info.get(x, {}).get(c, None))
df.head()
# Out:
#      pageid  first_date             first_rev  revid_two_weeks_prior  \
# 0    933889  2020_04_15  2020-04-17T00:00:00Z            947913373.0
# 1    565250  2020_05_15  2020-05-17T00:00:00Z            952606361.0
# 2   2473996  2020_04_21  2020-04-23T00:00:00Z            934033773.0
# 3    327694  2020_04_24  2020-04-26T00:00:00Z            944292122.0
# 4  28344340  2020_03_28  2020-03-30T00:00:00Z            933294732.0
#
#   revdate_two_weeks_prior  revid_two_weeks_later revdate_two_weeks_later
# 0    2020-03-29T04:28:48Z            951480151.0    2020-04-17T11:04:54Z
# 1    2020-04-23T03:42:29Z            956215718.0    2020-05-12T03:54:47Z
# 2    2020-01-04T11:09:51Z            934033773.0    2020-01-04T11:09:51Z
# 3    2020-03-06T22:20:21Z            952861522.0    2020-04-24T12:47:52Z
# 4    2019-12-31T02:30:46Z            933294732.0    2019-12-31T02:30:46Z

# %%
if False:  # Pandas way but no control over hammering the API
    with requests.Session() as session:
        sample['rev_two_weeks_ago'] = sample.apply(lambda x: revision_initial(page=x['pageid'], date=alter_date(date_str=x['first_date'], days=14, add=False), session=session), axis=1)
        sample['rev_two_weeks_after'] = sample.apply(lambda x: revision_initial(page=x['pageid'], date=alter_date(date_str=x['first_date'], days=14, add=True), session=session), axis=1)
# Out:
# /home/isaacj/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# save
df.to_csv('../social-media-traffic-reports/data/pageids_twoweekrevids.tsv', sep='\t')

# %%
# gather revision history in the two weeks on either side of the initial posting date for each article
rev_history = {}
with requests.Session() as session:
    for i, revids, times, sha1s in get_rev_history(df, 'pageid', 'revid_two_weeks_prior', 'revid_two_weeks_later'):
        pid = df.iloc[i]['pageid']        
        rev_history[pid] = (revids, times, sha1s)
        time.sleep(0.1)
        if len(rev_history) % 100 == 0:
            print("{0}/{1} complete".format(len(rev_history), len(df)))
# Out:
# 0/3324 processed.
# 50/3324 processed.
# Failed to get history: OrderedDict([('Index', 79), ('pageid', 63520964), ('first_date', '2020_04_05'), ('first_rev', '2020-04-07T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 951788304.0), ('revdate_two_weeks_later', '2020-04-18T22:02:27Z')])
# Failed to get history: OrderedDict([('Index', 93), ('pageid', 62750956), ('first_date', '2020_03_30'), ('first_rev', '2020-04-01T00:00:00Z'), ('revid_two_weeks_prior', 945762255.0), ('revdate_two_weeks_prior', '2020-03-15T23:57:53Z'), ('revid_two_weeks_later', 950609742.0), ('revdate_two_weeks_later', '2020-04-12T23:58:53Z')])
# 3324/3324 complete
# 100/3324 processed.
# Failed to get history: OrderedDict([('Index', 104), ('pageid', 48988415), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', 933825441.0), ('revdate_two_weeks_prior', '2020-01-03T06:13:58Z'), ('revid_two_weeks_later', 945682026.0), ('revdate_two_weeks_later', '2020-03-15T14:51:50Z')])
# Failed to get history: OrderedDict([('Index', 146), ('pageid', 32063857), ('first_date', '2020_04_23'), ('first_rev', '2020-04-25T00:00:00Z'), ('revid_two_weeks_prior', 948631092.0), ('revdate_two_weeks_prior', '2020-04-02T03:16:18Z'), ('revid_two_weeks_later', 955279097.0), ('revdate_two_weeks_later', '2020-05-06T22:45:59Z')])
# 150/3324 processed.
# 3324/3324 complete
# 200/3324 processed.
# 250/3324 processed.
# 3324/3324 complete
# Failed to get history: OrderedDict([('Index', 300), ('pageid', 11125478), ('first_date', '2020_03_31'), ('first_rev', '2020-04-02T00:00:00Z'), ('revid_two_weeks_prior', 945009345.0), ('revdate_two_weeks_prior', '2020-03-11T07:59:11Z'), ('revid_two_weeks_later', 950465076.0), ('revdate_two_weeks_later', '2020-04-12T06:57:25Z')])
# 300/3324 processed.
# Failed to get history: OrderedDict([('Index', 302), ('pageid', 63136490), ('first_date', '2020_03_16'), ('first_rev', '2020-03-18T00:00:00Z'), ('revid_two_weeks_prior', 943453819.0), ('revdate_two_weeks_prior', '2020-03-01T23:58:11Z'), ('revid_two_weeks_later', 948065464.0), ('revdate_two_weeks_later', '2020-03-29T23:48:12Z')])
# Failed to get history: OrderedDict([('Index', 328), ('pageid', 63488816), ('first_date', '2020_04_03'), ('first_rev', '2020-04-05T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 951375374.0), ('revdate_two_weeks_later', '2020-04-16T21:21:47Z')])
# 350/3324 processed.
# 3324/3324 complete
# 400/3324 processed.
# Failed to get history: OrderedDict([('Index', 436), ('pageid', 63300653), ('first_date', '2020_03_19'), ('first_rev', '2020-03-21T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 948569361.0), ('revdate_two_weeks_later', '2020-04-01T19:31:16Z')])
# 450/3324 processed.
# 3324/3324 complete
# 500/3324 processed.
# Failed to get history: OrderedDict([('Index', 516), ('pageid', 74982), ('first_date', '2020_03_31'), ('first_rev', '2020-04-02T00:00:00Z'), ('revid_two_weeks_prior', 945737372.0), ('revdate_two_weeks_prior', '2020-03-15T20:58:01Z'), ('revid_two_weeks_later', 950357534.0), ('revdate_two_weeks_later', '2020-04-11T17:26:35Z')])
# 550/3324 processed.
# Failed to get history: OrderedDict([('Index', 574), ('pageid', 63374708), ('first_date', '2020_03_20'), ('first_rev', '2020-03-22T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 948251457.0), ('revdate_two_weeks_later', '2020-03-31T00:13:33Z')])
# 3324/3324 complete
# 600/3324 processed.
# 650/3324 processed.
# Failed to get history: OrderedDict([('Index', 666), ('pageid', 46739727), ('first_date', '2020_04_21'), ('first_rev', '2020-04-23T00:00:00Z'), ('revid_two_weeks_prior', 945358997.0), ('revdate_two_weeks_prior', '2020-03-13T13:14:31Z'), ('revid_two_weeks_later', 954151324.0), ('revdate_two_weeks_later', '2020-04-30T23:08:47Z')])
# Failed to get history: OrderedDict([('Index', 694), ('pageid', 63661726), ('first_date', '2020_04_16'), ('first_rev', '2020-04-18T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 953964892.0), ('revdate_two_weeks_later', '2020-04-29T23:59:57Z')])
# 3324/3324 complete
# 700/3324 processed.
# Failed to get history: OrderedDict([('Index', 731), ('pageid', 63391478), ('first_date', '2020_03_30'), ('first_rev', '2020-04-01T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 950461406.0), ('revdate_two_weeks_later', '2020-04-12T06:27:20Z')])
# 750/3324 processed.
# Failed to get history: OrderedDict([('Index', 761), ('pageid', 63858312), ('first_date', '2020_05_08'), ('first_rev', '2020-05-10T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 957428753.0), ('revdate_two_weeks_later', '2020-05-18T20:17:16Z')])
# 3324/3324 complete
# 800/3324 processed.
# Failed to get history: OrderedDict([('Index', 811), ('pageid', 63716341), ('first_date', '2020_04_21'), ('first_rev', '2020-04-23T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 954679608.0), ('revdate_two_weeks_later', '2020-05-03T18:39:52Z')])
# Failed to get history: OrderedDict([('Index', 813), ('pageid', 63358914), ('first_date', '2020_03_16'), ('first_rev', '2020-03-18T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 948030190.0), ('revdate_two_weeks_later', '2020-03-29T20:02:04Z')])
# Failed to get history: OrderedDict([('Index', 843), ('pageid', 22677497), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', 940519634.0), ('revdate_two_weeks_prior', '2020-02-13T01:01:49Z'), ('revid_two_weeks_later', 947864751.0), ('revdate_two_weeks_later', '2020-03-28T22:50:20Z')])
# 850/3324 processed.
# Failed to get history: OrderedDict([('Index', 853), ('pageid', 12306449), ('first_date', '2020_03_24'), ('first_rev', '2020-03-26T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', nan), ('revdate_two_weeks_later', None)])
# 3324/3324 complete
# 900/3324 processed.
# Failed to get history: OrderedDict([('Index', 946), ('pageid', 45533434), ('first_date', '2020_04_25'), ('first_rev', '2020-04-27T00:00:00Z'), ('revid_two_weeks_prior', 949967187.0), ('revdate_two_weeks_prior', '2020-04-09T15:09:02Z'), ('revid_two_weeks_later', 954429118.0), ('revdate_two_weeks_later', '2020-05-02T10:34:29Z')])
# 950/3324 processed.
# Failed to get history: OrderedDict([('Index', 979), ('pageid', 57469264), ('first_date', '2020_03_23'), ('first_rev', '2020-03-25T00:00:00Z'), ('revid_two_weeks_prior', 944620941.0), ('revdate_two_weeks_prior', '2020-03-08T22:53:04Z'), ('revid_two_weeks_later', 949241949.0), ('revdate_two_weeks_later', '2020-04-05T10:54:56Z')])
# 3324/3324 complete
# 1000/3324 processed.
# 1050/3324 processed.
# Failed to get history: OrderedDict([('Index', 1069), ('pageid', 801890), ('first_date', '2020_04_04'), ('first_rev', '2020-04-06T00:00:00Z'), ('revid_two_weeks_prior', 945944539.0), ('revdate_two_weeks_prior', '2020-03-17T02:57:14Z'), ('revid_two_weeks_later', 950389977.0), ('revdate_two_weeks_later', '2020-04-11T20:56:27Z')])
# 3324/3324 complete
# 1100/3324 processed.
# 1150/3324 processed.
# Failed to get history: OrderedDict([('Index', 1185), ('pageid', 19377014), ('first_date', '2020_04_18'), ('first_rev', '2020-04-20T00:00:00Z'), ('revid_two_weeks_prior', 948240613.0), ('revdate_two_weeks_prior', '2020-03-30T22:42:09Z'), ('revid_two_weeks_later', 953697350.0), ('revdate_two_weeks_later', '2020-04-28T16:09:09Z')])
# 3324/3324 complete
# 1200/3324 processed.
# Failed to get history: OrderedDict([('Index', 1244), ('pageid', 62907297), ('first_date', '2020_03_22'), ('first_rev', '2020-03-24T00:00:00Z'), ('revid_two_weeks_prior', 944359256.0), ('revdate_two_weeks_prior', '2020-03-07T10:17:16Z'), ('revid_two_weeks_later', 949117659.0), ('revdate_two_weeks_later', '2020-04-04T19:45:17Z')])
# 1250/3324 processed.
# Failed to get history: OrderedDict([('Index', 1293), ('pageid', 63407978), ('first_date', '2020_03_26'), ('first_rev', '2020-03-28T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 949825250.0), ('revdate_two_weeks_later', '2020-04-08T18:58:32Z')])
# Failed to get history: OrderedDict([('Index', 1294), ('pageid', 896126), ('first_date', '2020_04_02'), ('first_rev', '2020-04-04T00:00:00Z'), ('revid_two_weeks_prior', 946157524.0), ('revdate_two_weeks_prior', '2020-03-18T13:17:44Z'), ('revid_two_weeks_later', 951175719.0), ('revdate_two_weeks_later', '2020-04-15T21:39:38Z')])
# 3324/3324 complete
# 1300/3324 processed.
# Failed to get history: OrderedDict([('Index', 1322), ('pageid', 2141388), ('first_date', '2020_05_11'), ('first_rev', '2020-05-13T00:00:00Z'), ('revid_two_weeks_prior', 947875167.0), ('revdate_two_weeks_prior', '2020-03-29T00:05:59Z'), ('revid_two_weeks_later', 956105228.0), ('revdate_two_weeks_later', '2020-05-11T14:50:36Z')])
# 1350/3324 processed.
# Failed to get history: OrderedDict([('Index', 1368), ('pageid', 20065598), ('first_date', '2020_04_18'), ('first_rev', '2020-04-20T00:00:00Z'), ('revid_two_weeks_prior', 948424689.0), ('revdate_two_weeks_prior', '2020-04-01T00:01:13Z'), ('revid_two_weeks_later', 954129789.0), ('revdate_two_weeks_later', '2020-04-30T20:46:43Z')])
# 3324/3324 complete
# 1400/3324 processed.
# Failed to get history: OrderedDict([('Index', 1404), ('pageid', 45943), ('first_date', '2020_05_04'), ('first_rev', '2020-05-06T00:00:00Z'), ('revid_two_weeks_prior', 951441194.0), ('revdate_two_weeks_prior', '2020-04-17T05:19:59Z'), ('revid_two_weeks_later', 957165824.0), ('revdate_two_weeks_later', '2020-05-17T11:26:39Z')])
# Failed to get history: OrderedDict([('Index', 1414), ('pageid', 63593359), ('first_date', '2020_04_07'), ('first_rev', '2020-04-09T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 949996431.0), ('revdate_two_weeks_later', '2020-04-09T18:15:51Z')])
# 1450/3324 processed.
# Failed to get history: OrderedDict([('Index', 1472), ('pageid', 44961355), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', 942271080.0), ('revdate_two_weeks_prior', '2020-02-23T17:51:03Z'), ('revid_two_weeks_later', 947615455.0), ('revdate_two_weeks_later', '2020-03-27T12:15:03Z')])
# Failed to get history: OrderedDict([('Index', 1482), ('pageid', 44653), ('first_date', '2020_05_03'), ('first_rev', '2020-05-05T00:00:00Z'), ('revid_two_weeks_prior', 950071441.0), ('revdate_two_weeks_prior', '2020-04-10T02:46:29Z'), ('revid_two_weeks_later', 956641757.0), ('revdate_two_weeks_later', '2020-05-14T13:35:10Z')])
# 3324/3324 complete
# 1500/3324 processed.
# Failed to get history: OrderedDict([('Index', 1507), ('pageid', 63786676), ('first_date', '2020_04_29'), ('first_rev', '2020-05-01T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 956272384.0), ('revdate_two_weeks_later', '2020-05-12T12:59:43Z')])
# 1550/3324 processed.
# Failed to get history: OrderedDict([('Index', 1566), ('pageid', 56864571), ('first_date', '2020_03_30'), ('first_rev', '2020-04-01T00:00:00Z'), ('revid_two_weeks_prior', 945732164.0), ('revdate_two_weeks_prior', '2020-03-15T20:26:00Z'), ('revid_two_weeks_later', 950337794.0), ('revdate_two_weeks_later', '2020-04-11T15:18:30Z')])
# Failed to get history: OrderedDict([('Index', 1584), ('pageid', 63598431), ('first_date', '2020_04_09'), ('first_rev', '2020-04-11T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 950643651.0), ('revdate_two_weeks_later', '2020-04-13T03:53:43Z')])
# Failed to get history: OrderedDict([('Index', 1587), ('pageid', 63262573), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947847595.0), ('revdate_two_weeks_later', '2020-03-28T20:52:09Z')])
# 3324/3324 complete
# 1600/3324 processed.
# 1650/3324 processed.
# 3324/3324 complete
# 1700/3324 processed.
# Failed to get history: OrderedDict([('Index', 1710), ('pageid', 48304260), ('first_date', '2020_03_23'), ('first_rev', '2020-03-25T00:00:00Z'), ('revid_two_weeks_prior', 943091745.0), ('revdate_two_weeks_prior', '2020-02-28T19:45:08Z'), ('revid_two_weeks_later', 948823605.0), ('revdate_two_weeks_later', '2020-04-03T06:32:30Z')])
# Failed to get history: OrderedDict([('Index', 1715), ('pageid', 523629), ('first_date', '2020_04_29'), ('first_rev', '2020-05-01T00:00:00Z'), ('revid_two_weeks_prior', 938703840.0), ('revdate_two_weeks_prior', '2020-02-01T21:37:04Z'), ('revid_two_weeks_later', 956303625.0), ('revdate_two_weeks_later', '2020-05-12T16:36:19Z')])
# 1750/3324 processed.
# Failed to get history: OrderedDict([('Index', 1764), ('pageid', 63443214), ('first_date', '2020_03_26'), ('first_rev', '2020-03-28T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 949844758.0), ('revdate_two_weeks_later', '2020-04-08T20:49:51Z')])
# 3324/3324 complete
# 1800/3324 processed.
# 1850/3324 processed.
# Failed to get history: OrderedDict([('Index', 1883), ('pageid', 9736746), ('first_date', '2020_04_06'), ('first_rev', '2020-04-08T00:00:00Z'), ('revid_two_weeks_prior', 946655578.0), ('revdate_two_weeks_prior', '2020-03-21T15:37:42Z'), ('revid_two_weeks_later', 951950315.0), ('revdate_two_weeks_later', '2020-04-19T19:45:05Z')])
# 3324/3324 complete
# 1900/3324 processed.
# Failed to get history: OrderedDict([('Index', 1931), ('pageid', 63705765), ('first_date', '2020_04_23'), ('first_rev', '2020-04-25T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 955274861.0), ('revdate_two_weeks_later', '2020-05-06T22:11:24Z')])
# 1950/3324 processed.
# Failed to get history: OrderedDict([('Index', 1984), ('pageid', 1553191), ('first_date', '2020_03_24'), ('first_rev', '2020-03-26T00:00:00Z'), ('revid_two_weeks_prior', 944450851.0), ('revdate_two_weeks_prior', '2020-03-07T22:44:06Z'), ('revid_two_weeks_later', 949380499.0), ('revdate_two_weeks_later', '2020-04-06T04:29:54Z')])
# 3324/3324 complete
# 2000/3324 processed.
# Failed to get history: OrderedDict([('Index', 2007), ('pageid', 63700453), ('first_date', '2020_04_24'), ('first_rev', '2020-04-26T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 954095655.0), ('revdate_two_weeks_later', '2020-04-30T17:17:48Z')])
# 2050/3324 processed.
# Failed to get history: OrderedDict([('Index', 2073), ('pageid', 52548620), ('first_date', '2020_04_06'), ('first_rev', '2020-04-08T00:00:00Z'), ('revid_two_weeks_prior', 946571446.0), ('revdate_two_weeks_prior', '2020-03-21T01:10:08Z'), ('revid_two_weeks_later', 951914471.0), ('revdate_two_weeks_later', '2020-04-19T15:39:45Z')])
# 3324/3324 complete
# 2100/3324 processed.
# 2150/3324 processed.
# 3324/3324 complete
# 2200/3324 processed.
# Failed to get history: OrderedDict([('Index', 2216), ('pageid', 63468897), ('first_date', '2020_03_30'), ('first_rev', '2020-04-01T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 948058809.0), ('revdate_two_weeks_later', '2020-03-29T22:54:41Z')])
# Failed to get history: OrderedDict([('Index', 2241), ('pageid', 63264158), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947873799.0), ('revdate_two_weeks_later', '2020-03-28T23:58:02Z')])
# Failed to get history: OrderedDict([('Index', 2246), ('pageid', 48887208), ('first_date', '2020_05_15'), ('first_rev', '2020-05-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', nan), ('revdate_two_weeks_later', None)])
# Failed to get history: OrderedDict([('Index', 2247), ('pageid', 58041212), ('first_date', '2020_05_04'), ('first_rev', '2020-05-06T00:00:00Z'), ('revid_two_weeks_prior', 951679626.0), ('revdate_two_weeks_prior', '2020-04-18T09:42:31Z'), ('revid_two_weeks_later', 957221699.0), ('revdate_two_weeks_later', '2020-05-17T18:19:29Z')])
# 2250/3324 processed.
# Failed to get history: OrderedDict([('Index', 2276), ('pageid', 63542764), ('first_date', '2020_04_16'), ('first_rev', '2020-04-18T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 953929616.0), ('revdate_two_weeks_later', '2020-04-29T19:59:06Z')])
# 3324/3324 complete
# 2300/3324 processed.
# Failed to get history: OrderedDict([('Index', 2301), ('pageid', 63378986), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', nan), ('revdate_two_weeks_later', None)])
# Failed to get history: OrderedDict([('Index', 2314), ('pageid', 63370168), ('first_date', '2020_03_25'), ('first_rev', '2020-03-27T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 949650518.0), ('revdate_two_weeks_later', '2020-04-07T18:34:20Z')])
# 2350/3324 processed.
# Failed to get history: OrderedDict([('Index', 2352), ('pageid', 63551161), ('first_date', '2020_04_03'), ('first_rev', '2020-04-05T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 951337508.0), ('revdate_two_weeks_later', '2020-04-16T17:45:45Z')])
# 3324/3324 complete
# 2400/3324 processed.
# Failed to get history: OrderedDict([('Index', 2411), ('pageid', 63657791), ('first_date', '2020_04_18'), ('first_rev', '2020-04-20T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 951742613.0), ('revdate_two_weeks_later', '2020-04-18T17:08:54Z')])
# Failed to get history: OrderedDict([('Index', 2421), ('pageid', 63510352), ('first_date', '2020_03_31'), ('first_rev', '2020-04-02T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 949252703.0), ('revdate_two_weeks_later', '2020-04-05T12:27:46Z')])
# Failed to get history: OrderedDict([('Index', 2424), ('pageid', 63739735), ('first_date', '2020_04_23'), ('first_rev', '2020-04-25T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 953862545.0), ('revdate_two_weeks_later', '2020-04-29T12:50:51Z')])
# 2450/3324 processed.
# Failed to get history: OrderedDict([('Index', 2451), ('pageid', 63862683), ('first_date', '2020_05_05'), ('first_rev', '2020-05-07T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 957429512.0), ('revdate_two_weeks_later', '2020-05-18T20:21:45Z')])
# Failed to get history: OrderedDict([('Index', 2468), ('pageid', 63346632), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947625591.0), ('revdate_two_weeks_later', '2020-03-27T13:54:13Z')])
# Failed to get history: OrderedDict([('Index', 2494), ('pageid', 63300608), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947869052.0), ('revdate_two_weeks_later', '2020-03-28T23:23:20Z')])
# 3324/3324 complete
# 2500/3324 processed.
# Failed to get history: OrderedDict([('Index', 2533), ('pageid', 63469659), ('first_date', '2020_04_06'), ('first_rev', '2020-04-08T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 951293351.0), ('revdate_two_weeks_later', '2020-04-16T13:09:50Z')])
# 2550/3324 processed.
# Failed to get history: OrderedDict([('Index', 2564), ('pageid', 47265), ('first_date', '2020_05_12'), ('first_rev', '2020-05-14T00:00:00Z'), ('revid_two_weeks_prior', 947754699.0), ('revdate_two_weeks_prior', '2020-03-28T07:40:21Z'), ('revid_two_weeks_later', 953629487.0), ('revdate_two_weeks_later', '2020-04-28T06:42:08Z')])
# 3324/3324 complete
# 2600/3324 processed.
# Failed to get history: OrderedDict([('Index', 2604), ('pageid', 63363332), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947862067.0), ('revdate_two_weeks_later', '2020-03-28T22:31:13Z')])
# 2650/3324 processed.
# 3324/3324 complete
# 2700/3324 processed.
# 2750/3324 processed.
# Failed to get history: OrderedDict([('Index', 2786), ('pageid', 17629865), ('first_date', '2020_03_17'), ('first_rev', '2020-03-19T00:00:00Z'), ('revid_two_weeks_prior', 943232554.0), ('revdate_two_weeks_prior', '2020-02-29T18:00:07Z'), ('revid_two_weeks_later', 948114804.0), ('revdate_two_weeks_later', '2020-03-30T06:37:13Z')])
# Failed to get history: OrderedDict([('Index', 2787), ('pageid', 63263950), ('first_date', '2020_03_15'), ('first_rev', '2020-03-17T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 947842569.0), ('revdate_two_weeks_later', '2020-03-28T20:19:25Z')])
# 3324/3324 complete
# 2800/3324 processed.
# 2850/3324 processed.
# Failed to get history: OrderedDict([('Index', 2860), ('pageid', 56196), ('first_date', '2020_04_21'), ('first_rev', '2020-04-23T00:00:00Z'), ('revid_two_weeks_prior', 949410224.0), ('revdate_two_weeks_prior', '2020-04-06T09:38:28Z'), ('revid_two_weeks_later', 954866373.0), ('revdate_two_weeks_later', '2020-05-04T18:21:12Z')])
# Failed to get history: OrderedDict([('Index', 2865), ('pageid', 50174864), ('first_date', '2020_03_22'), ('first_rev', '2020-03-24T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', nan), ('revdate_two_weeks_later', None)])
# 3324/3324 complete
# 2900/3324 processed.
# Failed to get history: OrderedDict([('Index', 2932), ('pageid', 3415107), ('first_date', '2020_05_02'), ('first_rev', '2020-05-04T00:00:00Z'), ('revid_two_weeks_prior', 943992919.0), ('revdate_two_weeks_prior', '2020-03-05T02:01:12Z'), ('revid_two_weeks_later', 955490878.0), ('revdate_two_weeks_later', '2020-05-08T03:14:22Z')])
# 2950/3324 processed.
# Failed to get history: OrderedDict([('Index', 2979), ('pageid', 63896761), ('first_date', '2020_05_08'), ('first_rev', '2020-05-10T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', nan), ('revdate_two_weeks_later', None)])
# 3324/3324 complete
# 3000/3324 processed.
# 3050/3324 processed.
# 3324/3324 complete
# 3100/3324 processed.
# 3150/3324 processed.
# Failed to get history: OrderedDict([('Index', 3156), ('pageid', 63888997), ('first_date', '2020_05_08'), ('first_rev', '2020-05-10T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 957408676.0), ('revdate_two_weeks_later', '2020-05-18T18:17:34Z')])
# Failed to get history: OrderedDict([('Index', 3160), ('pageid', 13721196), ('first_date', '2020_05_08'), ('first_rev', '2020-05-10T00:00:00Z'), ('revid_two_weeks_prior', 951188213.0), ('revdate_two_weeks_prior', '2020-04-15T23:02:17Z'), ('revid_two_weeks_later', 956993401.0), ('revdate_two_weeks_later', '2020-05-16T12:57:24Z')])
# 3324/3324 complete
# 3200/3324 processed.
# Failed to get history: OrderedDict([('Index', 3229), ('pageid', 63512325), ('first_date', '2020_03_30'), ('first_rev', '2020-04-01T00:00:00Z'), ('revid_two_weeks_prior', nan), ('revdate_two_weeks_prior', None), ('revid_two_weeks_later', 950608974.0), ('revdate_two_weeks_later', '2020-04-12T23:54:52Z')])
# 3250/3324 processed.
# Failed to get history: OrderedDict([('Index', 3297), ('pageid', 245693), ('first_date', '2020_04_28'), ('first_rev', '2020-04-30T00:00:00Z'), ('revid_two_weeks_prior', 950683083.0), ('revdate_two_weeks_prior', '2020-04-13T09:47:06Z'), ('revid_two_weeks_later', 955414750.0), ('revdate_two_weeks_later', '2020-05-07T17:48:54Z')])
# 3324/3324 complete
# 3300/3324 processed.
# Failed to get history: OrderedDict([('Index', 3314), ('pageid', 1581035), ('first_date', '2020_05_05'), ('first_rev', '2020-05-07T00:00:00Z'), ('revid_two_weeks_prior', 951057330.0), ('revdate_two_weeks_prior', '2020-04-15T07:47:43Z'), ('revid_two_weeks_later', 954953849.0), ('revdate_two_weeks_later', '2020-05-05T04:53:07Z')])

# %%
df['rev_history'] = df['pageid'].apply(lambda x: rev_history[x])

# %%
df.to_csv("../social-media-traffic-reports/data/pageids_revhistory.tsv", sep='\t')

# %%
df
# Out:
#         pageid  first_date             first_rev  revid_two_weeks_prior  \
# 0       933889  2020_04_15  2020-04-17T00:00:00Z            947913373.0
# 1       565250  2020_05_15  2020-05-17T00:00:00Z            952606361.0
# 2      2473996  2020_04_21  2020-04-23T00:00:00Z            934033773.0
# 3       327694  2020_04_24  2020-04-26T00:00:00Z            944292122.0
# 4     28344340  2020_03_28  2020-03-30T00:00:00Z            933294732.0
# 5      1359894  2020_04_27  2020-04-29T00:00:00Z            943189147.0
# 6        24600  2020_04_24  2020-04-26T00:00:00Z            949873401.0
# 7     55672859  2020_05_06  2020-05-08T00:00:00Z            950879883.0
# 8        73757  2020_03_20  2020-03-22T00:00:00Z            925017315.0
# 9      5160990  2020_04_20  2020-04-22T00:00:00Z            917041202.0
# 10      679967  2020_04_06  2020-04-08T00:00:00Z            946815519.0
# 11      958502  2020_04_08  2020-04-10T00:00:00Z            946576177.0
# 12     1572904  2020_04_14  2020-04-16T00:00:00Z            946962366.0
# 13     3765596  2020_05_11  2020-05-13T00:00:00Z            944279811.0
# 14      676502  2020_04_17  2020-04-19T00:00:00Z            946925163.0
# 15    10641459  2020_04_17  2020-04-19T00:00:00Z            944741147.0
# 16    20553781  2020_05_08  2020-05-10T00:00:00Z            918846782.0
# 17    62070839  2020_04_16  2020-04-18T00:00:00Z            947738010.0
# 18      262201  2020_03_22  2020-03-24T00:00:00Z            941501328.0
# 19     2662459  2020_04_23  2020-04-25T00:00:00Z            837374275.0
# 20      589885  2020_05_08  2020-05-10T00:00:00Z            951298938.0
# 21    15097921  2020_05_08  2020-05-10T00:00:00Z            941374773.0
# 22       73797  2020_03_19  2020-03-21T00:00:00Z            940978038.0
# 23       16459  2020_04_24  2020-04-26T00:00:00Z            944039853.0
# 24    45496853  2020_04_11  2020-04-13T00:00:00Z            941501953.0
# 25      294990  2020_04_14  2020-04-16T00:00:00Z            948137006.0
# 26    15409232  2020_03_30  2020-04-01T00:00:00Z            935431053.0
# 27    50446420  2020_05_13  2020-05-15T00:00:00Z            953597569.0
# 28       32191  2020_05_11  2020-05-13T00:00:00Z            953323593.0
# 29     4333654  2020_04_23  2020-04-25T00:00:00Z            945448596.0
# ...        ...         ...                   ...                    ...
# 3294  27855184  2020_04_24  2020-04-26T00:00:00Z            937755991.0
# 3295     16308  2020_04_26  2020-04-28T00:00:00Z            948266607.0
# 3296   3014582  2020_05_01  2020-05-03T00:00:00Z            947491722.0
# 3297    245693  2020_04_28  2020-04-30T00:00:00Z            950683083.0
# 3298    483263  2020_04_16  2020-04-18T00:00:00Z            948213391.0
# 3299     24512  2020_03_15  2020-03-17T00:00:00Z            939922891.0
# 3300     32708  2020_03_17  2020-03-19T00:00:00Z            942754113.0
# 3301   3227590  2020_03_30  2020-04-01T00:00:00Z            941820353.0
# 3302    384969  2020_05_10  2020-05-12T00:00:00Z            952351633.0
# 3303   1346180  2020_05_11  2020-05-13T00:00:00Z            952792192.0
# 3304  44662741  2020_03_19  2020-03-21T00:00:00Z            941698468.0
# 3305   3547094  2020_04_13  2020-04-15T00:00:00Z            943338396.0
# 3306    507864  2020_03_31  2020-04-02T00:00:00Z            945119464.0
# 3307  37385551  2020_05_16  2020-05-18T00:00:00Z            947400329.0
# 3308    606173  2020_03_15  2020-03-17T00:00:00Z            929259552.0
# 3309    163806  2020_04_16  2020-04-18T00:00:00Z            947348993.0
# 3310  26189791  2020_05_02  2020-05-04T00:00:00Z            949112450.0
# 3311   2760677  2020_05_07  2020-05-09T00:00:00Z            946993337.0
# 3312     32745  2020_05_08  2020-05-10T00:00:00Z            952711839.0
# 3313     81898  2020_04_23  2020-04-25T00:00:00Z            945052358.0
# 3314   1581035  2020_05_05  2020-05-07T00:00:00Z            951057330.0
# 3315    163824  2020_04_25  2020-04-27T00:00:00Z            945261779.0
# 3316   2441202  2020_05_10  2020-05-12T00:00:00Z            953059268.0
# 3317    345427  2020_04_05  2020-04-07T00:00:00Z            939310158.0
# 3318   9773044  2020_03_21  2020-03-23T00:00:00Z            938569982.0
# 3319    565237  2020_03_15  2020-03-17T00:00:00Z            940453911.0
# 3320    417785  2020_03_31  2020-04-02T00:00:00Z            937661209.0
# 3321   4604023  2020_04_16  2020-04-18T00:00:00Z            928271952.0
# 3322   1679356  2020_05_12  2020-05-14T00:00:00Z            951513885.0
# 3323  50724862  2020_03_29  2020-03-31T00:00:00Z            944710533.0
#
#      revdate_two_weeks_prior  revid_two_weeks_later revdate_two_weeks_later  \
# 0       2020-03-29T04:28:48Z            951480151.0    2020-04-17T11:04:54Z
# 1       2020-04-23T03:42:29Z            956215718.0    2020-05-12T03:54:47Z
# 2       2020-01-04T11:09:51Z            934033773.0    2020-01-04T11:09:51Z
# 3       2020-03-06T22:20:21Z            952861522.0    2020-04-24T12:47:52Z
# 4       2019-12-31T02:30:46Z            933294732.0    2019-12-31T02:30:46Z
# 5       2020-02-29T11:49:18Z            943189147.0    2020-02-29T11:49:18Z
# 6       2020-04-09T00:56:50Z            954700637.0    2020-05-03T20:48:05Z
# 7       2020-04-14T09:50:40Z            950879883.0    2020-04-14T09:50:40Z
# 8       2019-11-07T09:25:41Z            946659840.0    2020-03-21T16:11:14Z
# 9       2019-09-22T00:20:47Z            917041202.0    2019-09-22T00:20:47Z
# 10      2020-03-22T16:14:28Z            949765528.0    2020-04-08T12:04:16Z
# 11      2020-03-21T01:47:18Z            948031010.0    2020-03-29T20:08:41Z
# 12      2020-03-23T13:04:43Z            951373578.0    2020-04-16T21:12:06Z
# 13      2020-03-06T20:44:10Z            956085182.0    2020-05-11T12:35:21Z
# 14      2020-03-23T05:41:49Z            951645827.0    2020-04-18T04:26:36Z
# 15      2020-03-09T17:12:32Z            952126055.0    2020-04-20T18:01:56Z
# 16      2019-09-30T15:25:02Z            918846782.0    2019-09-30T15:25:02Z
# 17      2020-03-28T04:19:21Z            947738010.0    2020-03-28T04:19:21Z
# 18      2020-02-18T23:22:26Z            948907238.0    2020-04-03T17:49:38Z
# 19      2018-04-20T12:42:57Z            952360021.0    2020-04-21T21:18:25Z
# 20      2020-04-16T13:43:04Z            955304311.0    2020-05-07T02:21:54Z
# 21      2020-02-18T05:31:52Z            953171236.0    2020-04-26T01:45:01Z
# 22      2020-02-15T21:12:19Z            947160248.0    2020-03-24T17:34:16Z
# 23      2020-03-05T10:32:44Z            944039853.0    2020-03-05T10:32:44Z
# 24      2020-02-18T23:27:45Z            941501953.0    2020-02-18T23:27:45Z
# 25      2020-03-30T10:13:48Z            951289072.0    2020-04-16T12:37:20Z
# 26      2020-01-12T14:56:24Z            948467805.0    2020-04-01T05:27:29Z
# 27      2020-04-28T01:54:03Z            956542575.0    2020-05-13T23:17:14Z
# 28      2020-04-26T20:34:27Z            957314323.0    2020-05-18T06:18:57Z
# 29      2020-03-14T01:19:00Z            945448596.0    2020-03-14T01:19:00Z
# ...                      ...                    ...                     ...
# 3294    2020-01-27T02:06:17Z            955463962.0    2020-05-07T23:33:35Z
# 3295    2020-03-31T02:20:51Z            953689112.0    2020-04-28T15:16:43Z
# 3296    2020-03-26T17:13:35Z            954988103.0    2020-05-05T10:22:09Z
# 3297    2020-04-13T09:47:06Z            955414750.0    2020-05-07T17:48:54Z
# 3298    2020-03-30T19:32:13Z            952296995.0    2020-04-21T14:46:35Z
# 3299    2020-02-09T14:53:49Z            947642546.0    2020-03-27T16:01:10Z
# 3300    2020-02-26T16:51:36Z            947443384.0    2020-03-26T10:16:43Z
# 3301    2020-02-20T21:43:55Z            941820353.0    2020-02-20T21:43:55Z
# 3302    2020-04-21T20:24:51Z            957322601.0    2020-05-18T07:55:48Z
# 3303    2020-04-24T02:58:20Z            952792192.0    2020-04-24T02:58:20Z
# 3304    2020-02-20T03:52:49Z            941698468.0    2020-02-20T03:52:49Z
# 3305    2020-03-01T09:14:29Z            953063121.0    2020-04-25T14:40:21Z
# 3306    2020-03-11T22:44:44Z            947555512.0    2020-03-27T00:58:35Z
# 3307    2020-03-26T02:04:51Z            947400329.0    2020-03-26T02:04:51Z
# 3308    2019-12-04T17:25:09Z            946537330.0    2020-03-20T20:21:28Z
# 3309    2020-03-25T19:31:59Z            952670194.0    2020-04-23T13:25:42Z
# 3310    2020-04-04T19:16:45Z            954483883.0    2020-05-02T17:20:42Z
# 3311    2020-03-23T17:05:42Z            946993337.0    2020-03-23T17:05:42Z
# 3312    2020-04-23T18:11:38Z            957219424.0    2020-05-17T18:04:49Z
# 3313    2020-03-11T14:53:27Z            950730957.0    2020-04-13T15:07:24Z
# 3314    2020-04-15T07:47:43Z            954953849.0    2020-05-05T04:53:07Z
# 3315    2020-03-12T20:51:31Z            955195864.0    2020-05-06T13:28:24Z
# 3316    2020-04-25T14:11:02Z            957063305.0    2020-05-16T20:26:37Z
# 3317    2020-02-05T17:48:53Z            951513937.0    2020-04-17T15:13:49Z
# 3318    2020-02-01T00:41:45Z            938569982.0    2020-02-01T00:41:45Z
# 3319    2020-02-12T16:58:06Z            947645780.0    2020-03-27T16:23:55Z
# 3320    2020-01-26T11:58:28Z            949734346.0    2020-04-08T06:24:22Z
# 3321    2019-11-27T23:38:36Z            928271952.0    2019-11-27T23:38:36Z
# 3322    2020-04-17T15:13:28Z            957322179.0    2020-05-18T07:51:27Z
# 3323    2020-03-09T13:40:08Z            944710533.0    2020-03-09T13:40:08Z
#
#                                             rev_history
# 0     ([947913373, 951480151], [2020-03-29T04:28:48Z...
# 1     ([952606361, 954210710, 954916753, 956215718],...
# 2     ([934033773], [2020-01-04T11:09:51Z], [a78dc9d...
# 3     ([944292122, 952861439, 952861522], [2020-03-0...
# 4     ([933294732], [2019-12-31T02:30:46Z], [5a1a835...
# 5     ([943189147], [2020-02-29T11:49:18Z], [a1eb799...
# 6     ([949873401, 950118302, 950237060, 950549678, ...
# 7     ([950879883], [2020-04-14T09:50:40Z], [d28a77a...
# 8     ([925017315, 946659840], [2019-11-07T09:25:41Z...
# 9     ([917041202], [2019-09-22T00:20:47Z], [21a5cf1...
# 10    ([946815519, 947200181, 947200361, 947609927, ...
# 11    ([946576177, 948027713, 948028020, 948028259, ...
# 12    ([946962366, 950369052, 951373578], [2020-03-2...
# 13    ([944279811, 956081260, 956082020, 956082098, ...
# 14    ([946925163, 951645827], [2020-03-23T05:41:49Z...
# 15    ([944741147, 952126055], [2020-03-09T17:12:32Z...
# 16    ([918846782], [2019-09-30T15:25:02Z], [4112e5a...
# 17    ([947738010], [2020-03-28T04:19:21Z], [11d3e05...
# 18    ([941501328, 946753275, 946962850, 948907238],...
# 19    ([837374275, 952359932, 952360021], [2018-04-2...
# 20    ([951298938, 954597597, 954697887, 954697919, ...
# 21    ([941374773, 953171236], [2020-02-18T05:31:52Z...
# 22    ([940978038, 944359040, 945647585, 945736612, ...
# 23    ([944039853], [2020-03-05T10:32:44Z], [d8f5ad4...
# 24    ([941501953], [2020-02-18T23:27:45Z], [1f2aa13...
# 25    ([948137006, 951054791, 951289072], [2020-03-3...
# 26    ([935431053, 948467805], [2020-01-12T14:56:24Z...
# 27    ([953597569, 954113557, 954470181, 954587813, ...
# 28    ([953323593, 956667380, 956694656, 957314097, ...
# 29    ([945448596], [2020-03-14T01:19:00Z], [46382b5...
# ...                                                 ...
# 3294  ([937755991, 951319213, 952921419, 952926298, ...
# 3295  ([948266607, 951765139, 953166866, 953689112],...
# 3296  ([947491722, 952717880, 954006192, 954057756, ...
# 3297                                 (None, None, None)
# 3298  ([948213391, 948736567, 949828260, 951452750, ...
# 3299  ([939922891, 947339857, 947340158, 947637323, ...
# 3300  ([942754113, 945020074, 945026202, 945220084, ...
# 3301  ([941820353], [2020-02-20T21:43:55Z], [8596ad5...
# 3302  ([952351633, 954581754, 954582940, 954583042, ...
# 3303  ([952792192], [2020-04-24T02:58:20Z], [fda6da3...
# 3304  ([941698468], [2020-02-20T03:52:49Z], [9f3ede1...
# 3305  ([943338396, 950918498, 950918842, 950920014, ...
# 3306  ([945119464, 946412426, 946980234, 947535278, ...
# 3307  ([947400329], [2020-03-26T02:04:51Z], [ce30d61...
# 3308  ([929259552, 943838856, 945522934, 945523099, ...
# 3309  ([947348993, 952068191, 952670194], [2020-03-2...
# 3310  ([949112450, 954414982, 954471267, 954483883],...
# 3311  ([946993337], [2020-03-23T17:05:42Z], [06d415e...
# 3312  ([952711839, 952991314, 952994835, 952997916, ...
# 3313  ([945052358, 950730957], [2020-03-11T14:53:27Z...
# 3314                                 (None, None, None)
# 3315  ([945261779, 950569285, 950571124, 952331772, ...
# 3316  ([953059268, 956206573, 956211859, 956213131, ...
# 3317  ([939310158, 949208884, 951513937], [2020-02-0...
# 3318  ([938569982], [2020-02-01T00:41:45Z], [50d9424...
# 3319  ([940453911, 947387434, 947387506, 947645780],...
# 3320  ([937661209, 949734346], [2020-01-26T11:58:28Z...
# 3321  ([928271952], [2019-11-27T23:38:36Z], [352d4e3...
# 3322  ([951513885, 956181330, 957322179], [2020-04-1...
# 3323  ([944710533], [2020-03-09T13:40:08Z], [5a7c7b1...
#
# [3324 rows x 8 columns]

# %%
def count_edits_before(row):
    post_date = row['first_date'].replace('_', '-')
    if row['rev_history'][1] is not None:
        revs_before = [r for r in row['rev_history'][1] if r < post_date]
        return len(revs_before)
    return None

def count_edits_after(row):
    post_date = row['first_date'].replace('_', '-')
    if row['rev_history'][1] is not None:
        revs_before = [r for r in row['rev_history'][1] if r >= post_date]
        return len(revs_before)
    return None

def reverts_before(row):
    post_date = row['first_date'].replace('_', '-')
    if row['rev_history'][1] is not None:
        revs_before = [i for i, r in enumerate(row['rev_history'][1]) if r < post_date]
        num_reverts = get_num_reverts([r for i,r in enumerate(row['rev_history'][0]) if i in revs_before],
                                      [r for i,r in enumerate(row['rev_history'][1]) if i in revs_before],
                                      [r for i,r in enumerate(row['rev_history'][2]) if i in revs_before])
        return num_reverts
    return None
    
def reverts_after(row):
    post_date = row['first_date'].replace('_', '-')
    if row['rev_history'][1] is not None:
        revs_before = [i for i, r in enumerate(row['rev_history'][1]) if r >= post_date]
        num_reverts = get_num_reverts([r for i,r in enumerate(row['rev_history'][0]) if i in revs_before],
                                      [r for i,r in enumerate(row['rev_history'][1]) if i in revs_before],
                                      [r for i,r in enumerate(row['rev_history'][2]) if i in revs_before])
        return num_reverts
    return None

# %%
def ci_interval(col, alpha=0.01, num_iter=1000):
    true_avg = np.mean(col)
    ci = []
    for i in range(num_iter):
        iter_dat = col.sample(len(col), replace=True)
        iter_avg = np.mean(iter_dat)
        ci.append(iter_avg)
    ci = sorted(ci)
    return '{0:.3f} [{1:.3f}-{2:.3f}]'.format(true_avg,
                                              ci[int(num_iter * (alpha / 2))],
                                              ci[int(num_iter * (1 - (alpha / 2)))])

# %%
df['edits_before'] = df.apply(lambda x: count_edits_before(x), axis=1)
print("# edits before post: {0}".format(ci_interval(df['edits_before'])))
df['edits_after'] = df.apply(lambda x: count_edits_after(x), axis=1)
print("# edits after post: {0}".format(ci_interval(df['edits_after'])))
# Out:
# # edits before post: 10.698 [8.347-13.726]
# # edits after post: 10.848 [8.551-13.286]

# %%
df['reverts_before'] = df.apply(lambda x: reverts_before(x), axis=1)
print("# reverts before post: {0}".format(ci_interval(df['reverts_before'])))
df['reverts_after'] = df.apply(lambda x: reverts_after(x), axis=1)
print("# reverts after post: {0}".format(ci_interval(df['reverts_after'])))
# Out:
# # reverts before post: 0.833 [0.695-0.994]
# # reverts after post: 0.831 [0.698-0.981]
